# %%
###################################################################################
#                                                                                 #
#                BUNDLING CSV XRAIN DATA INTO A SINGLE SHAPEFILE (GIS)            #
#                                                                                 #
#                             Christopher Gomez, 2024                             #
#                                                                                 #
###################################################################################


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import glob
import os
from datetime import datetime

def create_grid_shapefile_with_data(northwest_corner, southeast_corner, n_rows, n_cols, data_folder, output_file):
    """
    Create a georeferenced grid shapefile with time-series data from CSV files.
    
    Parameters:
    -----------
    northwest_corner: tuple
        (latitude, longitude) of northwest corner
    southeast_corner: tuple
        (latitude, longitude) of southeast corner
    n_rows: int
        Number of rows in the grid
    n_cols: int
        Number of columns in the grid
    data_folder: str
        Path to folder containing CSV files
    output_file: str
        Path for output shapefile
    """
    print("Creating grid geometry...")
    
    # Calculate cell dimensions
    lat_step = (northwest_corner[0] - southeast_corner[0]) / n_rows
    lon_step = (southeast_corner[1] - northwest_corner[1]) / n_cols
    
    # Create empty lists to store geometries and attributes
    geometries = []
    cells = []
    
    # Generate grid cells and store their indices
    for row in range(n_rows):
        for col in range(n_cols):
            # Calculate corner coordinates for each cell
            north = northwest_corner[0] - (row * lat_step)
            south = north - lat_step
            west = northwest_corner[1] + (col * lon_step)
            east = west + lon_step
            
            # Create polygon for the cell
            cell = Polygon([
                (west, north),
                (east, north),
                (east, south),
                (west, south),
                (west, north)
            ])
            
            geometries.append(cell)
            cells.append({'geometry': cell, 'row': row, 'col': col})
    
    # Create initial GeoDataFrame with the grid
    grid_gdf = gpd.GeoDataFrame(cells)
    
    # Set CRS to WGS 84
    grid_gdf.set_crs(epsg=4326, inplace=True)
    
    print("Processing CSV files...")
    
    # Get list of all CSV files in the folder
    csv_files = sorted(glob.glob(os.path.join(data_folder, '*.csv')))
    
    # Process each CSV file
    for csv_file in csv_files:
        try:
            # Extract timestamp from filename (assuming format YYYYMMDD-HHMM)
            timestamp = datetime.strptime(os.path.basename(csv_file)[:13], '%Y%m%d-%H%M')
            print(f"Processing file for timestamp: {timestamp}")
            
            # Read CSV file
            df = pd.read_csv(csv_file, header=None)
            
            if df.shape != (n_rows, n_cols):
                print(f"Warning: CSV file {csv_file} has unexpected dimensions: {df.shape}")
                continue
            
            # Create a list to store values in the same order as our grid cells
            values = []
            for row in range(n_rows):
                for col in range(n_cols):
                    values.append(df.iloc[row, col])
            
            # Add the values as a new column in the GeoDataFrame
            column_name = f'T{timestamp.strftime("%Y%m%d_%H%M")}'
            grid_gdf[column_name] = values
            
        except Exception as e:
            print(f"Error processing file {csv_file}: {str(e)}")
    
    print("Saving shapefile...")
    
    # Save to shapefile
    grid_gdf.to_file(output_file)
    
    print(f"Complete! Shapefile saved to {output_file}")
    print(f"Number of time steps processed: {len(csv_files)}")
    
    return grid_gdf

# Example usage
if __name__ == "__main__":
    # Define parameters based on your data
    nw_corner = (37.7584, 136.0218)  # (lat, lon)
    se_corner = (36.2813, 137.8781)  # (lat, lon)
    n_rows = 709
    n_cols = 594
    
    # Create the grid shapefile with data
    grid_gdf = create_grid_shapefile_with_data(
        northwest_corner=nw_corner,
        southeast_corner=se_corner,
        n_rows=n_rows,
        n_cols=n_cols,
        data_folder=os.getcwd(),  # Current working directory
        output_file='temporal_grid_with_data.shp'
    )
# Out:
# Creating grid geometry...
# Processing CSV files...
# Processing file for timestamp: 2024-09-20 12:10:00
# Processing file for timestamp: 2024-09-20 12:20:00
# Processing file for timestamp: 2024-09-20 12:30:00
# Processing file for timestamp: 2024-09-20 12:40:00
# Processing file for timestamp: 2024-09-20 12:50:00
# Processing file for timestamp: 2024-09-20 13:00:00
# Processing file for timestamp: 2024-09-20 13:10:00
# Processing file for timestamp: 2024-09-20 13:20:00
# Processing file for timestamp: 2024-09-20 13:30:00
# Processing file for timestamp: 2024-09-20 13:40:00
# Processing file for timestamp: 2024-09-20 13:50:00
# Processing file for timestamp: 2024-09-20 14:00:00
# Processing file for timestamp: 2024-09-20 14:10:00
# Processing file for timestamp: 2024-09-20 14:20:00
# Processing file for timestamp: 2024-09-20 14:30:00
# Processing file for timestamp: 2024-09-20 14:40:00
# Processing file for timestamp: 2024-09-20 14:50:00
# Processing file for timestamp: 2024-09-20 15:00:00
# Processing file for timestamp: 2024-09-20 15:10:00
# Processing file for timestamp: 2024-09-20 15:20:00
# Processing file for timestamp: 2024-09-20 15:30:00
# Processing file for timestamp: 2024-09-20 15:40:00
# Processing file for timestamp: 2024-09-20 15:50:00
# Processing file for timestamp: 2024-09-20 16:00:00
# Processing file for timestamp: 2024-09-20 16:10:00
# Processing file for timestamp: 2024-09-20 16:20:00
# Processing file for timestamp: 2024-09-20 16:30:00
# Processing file for timestamp: 2024-09-20 16:40:00
# Processing file for timestamp: 2024-09-20 16:50:00
# Processing file for timestamp: 2024-09-20 17:00:00
# Processing file for timestamp: 2024-09-20 17:10:00
# Processing file for timestamp: 2024-09-20 17:20:00
# Processing file for timestamp: 2024-09-20 17:30:00
# Processing file for timestamp: 2024-09-20 17:40:00
# Processing file for timestamp: 2024-09-20 17:50:00
# Processing file for timestamp: 2024-09-20 18:00:00
# Processing file for timestamp: 2024-09-20 18:10:00
# Processing file for timestamp: 2024-09-20 18:20:00
# Processing file for timestamp: 2024-09-20 18:30:00
# Processing file for timestamp: 2024-09-20 18:40:00
# Processing file for timestamp: 2024-09-20 18:50:00
# Processing file for timestamp: 2024-09-20 19:00:00
# Processing file for timestamp: 2024-09-20 19:10:00
# Processing file for timestamp: 2024-09-20 19:20:00
# Processing file for timestamp: 2024-09-20 19:30:00
# Processing file for timestamp: 2024-09-20 19:40:00
# Processing file for timestamp: 2024-09-20 19:50:00
# Processing file for timestamp: 2024-09-20 20:00:00
# Processing file for timestamp: 2024-09-20 20:10:00
# Processing file for timestamp: 2024-09-20 20:20:00
# Processing file for timestamp: 2024-09-20 20:30:00
# Processing file for timestamp: 2024-09-20 20:40:00
# Processing file for timestamp: 2024-09-20 20:50:00
# Processing file for timestamp: 2024-09-20 21:00:00
# Processing file for timestamp: 2024-09-20 21:10:00
# Processing file for timestamp: 2024-09-20 21:20:00
# Processing file for timestamp: 2024-09-20 21:30:00
# Processing file for timestamp: 2024-09-20 21:40:00
# Processing file for timestamp: 2024-09-20 21:50:00
# Processing file for timestamp: 2024-09-20 22:00:00
# Processing file for timestamp: 2024-09-20 22:10:00
# Processing file for timestamp: 2024-09-20 22:20:00
# Processing file for timestamp: 2024-09-20 22:30:00
# Processing file for timestamp: 2024-09-20 22:40:00
# Processing file for timestamp: 2024-09-20 22:50:00
# Processing file for timestamp: 2024-09-20 23:00:00
# Processing file for timestamp: 2024-09-20 23:10:00
# Processing file for timestamp: 2024-09-20 23:20:00
# Processing file for timestamp: 2024-09-20 23:30:00
# Processing file for timestamp: 2024-09-20 23:40:00
# Processing file for timestamp: 2024-09-20 23:50:00
# Saving shapefile...
# C:\Users\kaiki\AppData\Local\Temp\ipykernel_17348\1570416035.py:99: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   grid_gdf.to_file(output_file)
# Complete! Shapefile saved to temporal_grid_with_data.shp
# Number of time steps processed: 71
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1210' to 'T20240920_'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1220' to 'T2024092_1'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1230' to 'T2024092_2'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1240' to 'T2024092_3'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1250' to 'T2024092_4'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1300' to 'T2024092_5'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1310' to 'T2024092_6'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1320' to 'T2024092_7'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1330' to 'T2024092_8'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1340' to 'T2024092_9'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1350' to 'T202409210'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1400' to 'T202409211'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1410' to 'T202409212'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1420' to 'T202409213'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1430' to 'T202409214'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1440' to 'T202409215'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1450' to 'T202409216'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1500' to 'T202409217'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1510' to 'T202409218'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1520' to 'T202409219'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1530' to 'T202409220'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1540' to 'T202409221'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1550' to 'T202409222'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1600' to 'T202409223'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1610' to 'T202409224'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1620' to 'T202409225'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1630' to 'T202409226'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1640' to 'T202409227'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1650' to 'T202409228'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1700' to 'T202409229'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1710' to 'T202409230'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1720' to 'T202409231'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1730' to 'T202409232'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1740' to 'T202409233'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1750' to 'T202409234'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1800' to 'T202409235'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1810' to 'T202409236'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1820' to 'T202409237'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1830' to 'T202409238'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1840' to 'T202409239'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1850' to 'T202409240'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1900' to 'T202409241'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1910' to 'T202409242'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1920' to 'T202409243'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1930' to 'T202409244'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1940' to 'T202409245'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_1950' to 'T202409246'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2000' to 'T202409247'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2010' to 'T202409248'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2020' to 'T202409249'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2030' to 'T202409250'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2040' to 'T202409251'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2050' to 'T202409252'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2100' to 'T202409253'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2110' to 'T202409254'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2120' to 'T202409255'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2130' to 'T202409256'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2140' to 'T202409257'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2150' to 'T202409258'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2200' to 'T202409259'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2210' to 'T202409260'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2220' to 'T202409261'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2230' to 'T202409262'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2240' to 'T202409263'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2250' to 'T202409264'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2300' to 'T202409265'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2310' to 'T202409266'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2320' to 'T202409267'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2330' to 'T202409268'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2340' to 'T202409269'
#   ogr_write(
# C:\Users\kaiki\anaconda3\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'T20240920_2350' to 'T202409270'
#   ogr_write(
